# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import re
import time

# %%
url = 'https://www.flipkart.com/search?q=mobiles&otracker=AS_Query_HistoryAutoSuggest_2_0&otracker1=AS_Query_HistoryAutoSuggest_2_0&marketplace=FLIPKART&as-show=on&as=off&as-pos=2&as-type=HISTORY&p%5B%5D=facets.price_range.from%3DMin&p%5B%5D=facets.price_range.to%3D50000&p%5B%5D=facets.brand%255B%255D%3Drealme&p%5B%5D=facets.brand%255B%255D%3DPOCO&p%5B%5D=facets.brand%255B%255D%3DInfinix&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DMi&p%5B%5D=facets.brand%255B%255D%3DBlackBerry&p%5B%5D=facets.brand%255B%255D%3DCelkon&p%5B%5D=facets.brand%255B%255D%3DDELL&p%5B%5D=facets.brand%255B%255D%3DGIVA&p%5B%5D=facets.brand%255B%255D%3DHonor&p%5B%5D=facets.brand%255B%255D%3DHTC&p%5B%5D=facets.brand%255B%255D%3DHP&p%5B%5D=facets.brand%255B%255D%3DHuawei&p%5B%5D=facets.brand%255B%255D%3Diball&p%5B%5D=facets.brand%255B%255D%3DINOVU&p%5B%5D=facets.brand%255B%255D%3DInfocus&p%5B%5D=facets.brand%255B%255D%3DIntex&p%5B%5D=facets.brand%255B%255D%3DItel&p%5B%5D=facets.brand%255B%255D%3DKARBONN&p%5B%5D=facets.brand%255B%255D%3DLAVA&p%5B%5D=facets.brand%255B%255D%3DLenovo&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMICROSOFT&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DPHILIPS&p%5B%5D=facets.brand%255B%255D%3DPanasonic&p%5B%5D=facets.brand%255B%255D%3DREDMI&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DSony%2BEricsson&p%5B%5D=facets.brand%255B%255D%3Dvivo&p%5B%5D=facets.brand%255B%255D%3DVodafone&p%5B%5D=facets.brand%255B%255D%3DZen'

# %%
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
pagecontent = page.text

# %%
pagecontent
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.116d54.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png"/><link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png"/><link rel="apple-touch-icon" href="/apple-touch-icon-57x57.png"/><meta name="twitter:card" content="app"><meta name="twitter:site" content="@flipkart"><meta name="twitter:creator" content="@flipkart"><meta name="twitter:title" content="Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com"><meta name="twitter:description" content="Shop for electronics, apparels & more using our Flipkart app Free shipping & COD."><meta name="twitter:app:country" content="in"><meta name="al:ios:app_name" content="Flipkart"><meta name="al:ios:app_store_id" content="742044692"><meta name="twitter:app:name:iphone" content="Flipkart"><meta name="twitter:app:id:iphone" content="742044692"><meta name="twitter:app:url:iphone" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:ipad" content="Flipkart"><meta name="twitter:app:id:ipad" content="742044692"><meta name="twitter:app:url:ipad" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:googleplay" content="Flipkart"><meta name="twitter:app:id:googleplay" content="com.flipkart.android"><meta name="twitter:app:url:googleplay" content="http://dl.flipkart.com/dl/home?"><style>#container {\n\t\t\theight: 100%;\n\t\t}</style><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/runtime.a0b18988.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/vendor.chunk.c8c2cf34.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_modules.chunk.18c97287.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_common.chunk.fc484817.js" defer="defer" crossorigin="anonymous"></script><script src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app.chunk.4f49454b.js" defer="defer" crossorigin="anonymous"></script><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/Browse.chunk.3c807f.css"/><title>Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title><meta name="og_title" property="og:title" content="Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com"/><meta name="Keywords" content="Mobiles"/> <meta name="Description" content="Mobiles- Buy Products Online at Best Price in India. India&#x27;s Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com"/><meta property="og:description" content="Mobiles- Buy Products Online at Best Price in India. India&#x27;s Leading E-commerce Company - Free Home Delive ...

# %%
soup = BeautifulSoup(pagecontent)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.116d54.css" rel="stylesheet"/><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="102988293558" property="fb:page_id"/><meta content="658873552,624500995,100000233612389" property="fb:admins"/><meta content="noodp" name="robots"/><link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/><link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/><meta content="website" property="og:type"/><meta content="Flipkart.com" name="og_site_name" property="og:site_name"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/><meta content="app" name="twitter:card"/><meta content="@flipkart" name="twitter:site"/><meta content="@flipkart" name="twitter:creator"/><meta content="Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="twitter:title"/><meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/><meta content="in" name="twitter:app:country"/><meta content="Flipkart" name="al:ios:app_name"/><meta content="742044692" name="al:ios:app_store_id"/><meta content="Flipkart" name="twitter:app:name:iphone"/><meta content="742044692" name="twitter:app:id:iphone"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/><meta content="Flipkart" name="twitter:app:name:ipad"/><meta content="742044692" name="twitter:app:id:ipad"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/><meta content="Flipkart" name="twitter:app:name:googleplay"/><meta content="com.flipkart.android" name="twitter:app:id:googleplay"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/><style>#container {
# 			height: 100%;
# 		}</style><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/runtime.a0b18988.js"></script><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/vendor.chunk.c8c2cf34.js"></script><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_modules.chunk.18c97287.js"></script><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app_common.chunk.fc484817.js"></script><script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/app.chunk.4f49454b.js"></script><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/Browse.chunk.3c807f.css" rel="stylesheet"/><title>Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title><meta content="Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="og_title" property="og:title"/><meta content="Mobiles" name="Keywords"/> <meta content="Mobiles- Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" name="Description"/><meta content="Mobiles- Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" property="og:description"/> <meta content="noindex" name="robots"/> <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01"/> <!--[if IE 9 ]>
# 	<script nonce="11285717659153663253">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]--><!--[if !IE]><!--><script nonce="11285717659153663253">if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}</script><!--<![endif]--> <link href="https://www.flipkart.com/search?q=mobiles&amp;otracker=AS_Query_HistoryAutoSuggest_2_0&amp;otracker1=AS_Query_HistoryAutoSuggest_2_0&amp;marketplace=FLIPKART&amp;as-show=on&amp;as=off&amp;as-pos=2&amp;as-type=HISTORY&amp;p%5B%5D=facets.price_range.from%3DMin&amp;p%5B%5D=facets.price_range.to%3D50000&amp;p%5B%5D=facets.brand%255B%255D%3Drealme&amp;p%5B%5D=facets.brand%255B%255D%3DPOCO&amp;p%5B%5D=facets.brand%255B%255D%3DInfinix&amp;p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&amp;p%5B%5D=facets.brand%255B%255D%3DMi&amp;p%5B%5D=facets.brand%255B%255D%3DBlackBerry&amp;p%5B%5D=facets.brand%255B%255D%3DCelkon&amp;p%5B%5D=facets.brand%255B%255D%3DDELL&amp;p%5B%5D=facets.brand%255B%255D%3DGIVA&amp;p%5B%5D=facets.brand%255B%255D%3DHonor&amp;p%5B%5D=facets.brand%255B%255D%3DHTC&amp;p%5B%5D=facets.brand%255B%255D%3DHP&amp;p%5B%5D=facets.brand%255B%255D%3DHuawei&amp;p%5B%5D=facets.brand%255B%255D%3Diball&amp;p%5B%5D=facets.brand%255B%255D%3DINOVU&amp;p%5B%5D=facets.brand%255B%255D%3DInfocus&amp;p%5B%5D=facets.brand%255B%255D%3DIntex&amp;p%5B%5D=facets.brand%255B%255D%3DItel&amp;p%5B%5D=facets.brand%255B%255D%3DKARBONN&amp;p%5B%5D=facets.brand%255B%255D%3DLAVA&amp;p%5B%5D=facets.brand%255B%255D%3DLenovo&amp;p%5B%5D=facets.brand%255B%255D%3DLG&amp;p%5B%5D=facets.brand%255B%255D%3DMICROSOFT&amp;p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&amp;p%5B%5D=facets.brand%255B%255D%3DPHILIPS&amp;p%5B%5D=facets.brand%255B%255D%3DPanasonic&amp;p%5B%5D=facets.brand%255B%255D%3DREDMI&amp;p%5B%5D=facets.brand%255B%255D%3DSONY&amp;p%5B%5D=facets.brand%255B%255D%3DSony%2BEricsson&amp;p%5B%5D=facets.brand%255B%255D%3Dvivo&amp;p%5B%5D=facets.brand%255B%255D%3DVodafone&amp;p%5B%5D=facets.brand%255B%255D%3DZen&amp;page=2" id="next-page-link-tag" rel="next"/><script nonce="11285717659153663253">!function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#
# 		if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#
#         // web-vitals polyfill for FID
#         !function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script></head><body><div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value="mobiles"/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill="#2874F1" fill-rule="evenodd"><path class="_34RNph" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203"></path><path class="_34RNph" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467"></path></g></svg></button><input name="otracker" type="hidden" value="search"/><input name="otracker1" type="hidden" value="search"/><input name="marketplace" type="hidden" value="FLIPKART"/><input name="as-show" type="hidden" value="off"/><input name="as" type="hidden" value="off"/></div><ul class="col-12-12 _1MRYA1"></ul></form></div><div class="go_DOp _2errNR"><div class="_28p97w"><div class="_1psGvi _3BvnxG"><div><a class="_1_3w1N" href="/account/login?ret=/search%3Fq%3Dmobiles%26otracker%3DAS_Query_HistoryAutoSuggest_2_0%26otracker1%3DAS_Query_HistoryAutoSuggest_2_0%26marketplace%3DFLIPKART%26as-show%3Don%26as%3Doff%26as-pos%3D2%26as-type%3DHISTORY%26p%255B%255D%3Dfacets.price_range.from%253DMin%26p%255B%255D%3Dfacets.price_range.to%253D50000%26p%255B%255D%3Dfacets.brand%25255B%25255D%253Drealme%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DPOCO%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DInfinix%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DSAMSUNG%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DMi%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DBlackBerry%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DCelkon%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DDELL%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DGIVA%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DHonor%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DHTC%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DHP%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DHuawei%26p%255B%255D%3Dfacets.brand%25255B%25255D%253Diball%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DINOVU%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DInfocus%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DIntex%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DItel%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DKARBONN%26p%255B%255D%3Dfacets.brand%25255B ...
# <p> Buildings Alyssa, Begonia &amp; </p>
# <p> Clove Embassy Tech Village, </p>
# <p> Outer Ring Road, Devarabeesanahalli Village, </p>
# <p> Bengaluru, 560103, </p>
# <p> Karnataka, India</p>
# </div></div></div></div></div><div class="_2Brcj4 address"><div class="_3IT4e6"><div class="_3-dnWo"><span>Registered Office Address:</span></div><div class="_1U1qnR"><div class="_1LJS6T"><div class="_2NKhZn _1U1qnR"><p>Flipkart Internet Private Limited, </p>
# <p> Buildings Alyssa, Begonia &amp; </p>
# <p> Clove Embassy Tech Village, </p>
# <p> Outer Ring Road, Devarabeesanahalli Village, </p>
# <p> Bengaluru, 560103, </p>
# <p> Karnataka, India </p>
# <p> CIN : U51109KA2012PTC066107 </p>
# <p> Telephone: <a href="tel:18002029898">044-45614700</a></p>
# </div></div></div></div></div></div><div><div class="_2uz0vJ"><div><img src="data:image/svg+xml;base64,..."/><a href="https://seller.flipkart.com/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span class="hDTmm5">Become a Seller</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="https://brands.flipkart.com"><span class="hDTmm5">Advertise</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="/the-gift-card-store?otracker=undefined_footer_footer_navlinks"><span class="hDTmm5">Gift Cards</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="/helpcentre?otracker=undefined_footer_footer_navlinks"><span class="hDTmm5">Help Center</span></a></div><span class="z3ht-w">© 2007-<!-- -->2022<!-- --> <span>Flipkart.com</span></span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/payment-method_69e7ec.svg"/></div></div></div></div></footer><div class="_1EcK2J _38JCdA"><div class="bra6U8"><svg class="_2TdLiZ" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_3ZKfA2" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg><span>Back to top</span></div></div></div></div> <script id="jsonLD" nonce="11285717659153663253" type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.flipkart.com/poco-c31-royal-blue-64-gb/p/itm19effae969b86?pid=MOBG73E7GKQK4KZP&lid=LSTMOBG73E7GKQK4KZPR5ICMK&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"POCO C31 (Royal Blue, 64 GB)"},{"@type":"ListItem","position":2,"url":"https://www.flipkart.com/samsung-galaxy-f22-denim-blue-64-gb/p/itmce0a6baf0d54d?pid=MOBG43UGBTGGB99V&lid=LSTMOBG43UGBTGGB99VLZACSD&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"SAMSUNG Galaxy F22 (Denim Blue, 64 GB)"},{"@type":"ListItem","position":3,"url":"https://www.flipkart.com/poco-c31-royal-blue-32-gb/p/itm9656ebd21e0b3?pid=MOBG73E7ZBHHQ3RB&lid=LSTMOBG73E7ZBHHQ3RBDYSPVO&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"POCO C31 (Royal Blue, 32 GB)"},{"@type":"ListItem","position":4,"url":"https://www.flipkart.com/poco-c31-shadow-gray-64-gb/p/itm162375acb8370?pid=MOBG73E7UBFXXMCH&lid=LSTMOBG73E7UBFXXMCHSM0ZN5&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"POCO C31 (Shadow Gray, 64 GB)"},{"@type":"ListItem","position":5,"url":"https://www.flipkart.com/infinix-hot-12-play-horizon-blue-64-gb/p/itmd9c1091d0a662?pid=MOBGE2KYCFZA7BRB&lid=LSTMOBGE2KYCFZA7BRBUNTJVL&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"Infinix HOT 12 Play (Horizon Blue, 64 GB)"},{"@type":"ListItem","position":6,"url":"https://www.flipkart.com/realme-9-sunburst-gold-128-gb/p/itm73722a6d35d36?pid=MOBGDYSHHVWMECHS&lid=LSTMOBGDYSHHVWMECHSANSMZ4&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"realme 9 (Sunburst Gold, 128 GB)"},{"@type":"ListItem","position":7,"url":"https://www.flipkart.com/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&lid=LSTMOBG43UGC3PYCBZFSIRYTE&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"SAMSUNG Galaxy F22 (Denim Black, 64 GB)"},{"@type":"ListItem","position":8,"url":"https://www.flipkart.com/realme-c31-dark-green-32-gb/p/itme0f2960da9bbb?pid=MOBGCGVAXYT3EGYR&lid=LSTMOBGCGVAXYT3EGYRW8CSTQ&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"realme C31 (Dark Green, 32 GB)"},{"@type":"ListItem","position":9,"url":"https://www.flipkart.com/realme-c11-2021-cool-blue-32-gb/p/itmbd856acb97c38?pid=MOBG4BEG3HG78BDG&lid=LSTMOBG4BEG3HG78BDGZKVJB6&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"realme C11 2021 (Cool Blue, 32 GB)"},{"@type":"ListItem","position":10,"url":"https://www.flipkart.com/realme-c11-2021-cool-grey-32-gb/p/itmbd856acb97c38?pid=MOBG4BEGX8QYNKGZ&lid=LSTMOBG4BEGX8QYNKGZ8JGQTA&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io","name":"realme C11 2021 (Cool Grey, 32 GB)"}]}</script> <script id="js ...
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }</script><script id="is_script" nonce="11285717659153663253">window.__INITIAL_STATE__ = {"abExperiments":{"bucket[]":{"value":"matching_control_AA_7th_July_2022_14mods","abId":"006d7b44","expId":"matching_control_AA_7th_July_2022_14mods"},"trackingId":{"value":"matching_control_AA_7th_July_2022_14mods","abId":"006d7b44","expId":"matching_control_AA_7th_July_2022_14mods"},"showNewSeasonTag":{"value":true,"abId":"07eea72a","expId":"GH | New Season Tag across the funnel"},"user_token_consent_nudge":{"value":2,"abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"INSTRUMENT_DISPLAY_NAME_AB_EXPERIMENT_msite":{"value":false,"abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"INSTRUMENT_DISPLAY_NAME_AB_EXPERIMENT_android":{"value":false,"abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"INSTRUMENT_RANK_CHANGE_NU_EXP_NAME_msite":{"value":"default","abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"INSTRUMENT_RANK_CHANGE_EXP_NAME_android":{"value":"default","abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"SC_PAY":{"value":2,"abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"INSTRUMENT_RANK_CHANGE_NU_EXP_NAME_android":{"value":"default","abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"INSTRUMENT_RANK_CHANGE_EXP_NAME_msite":{"value":"default","abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"captcha_v4_on_ios":{"value":2,"abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"fpl_split_payments":{"value":2,"abId":"18dad9a4","expId":"Payment Page Control 2 (25 mods)"},"voicePostUrl":{"value":"https://voice.flipkart.net/1/speech/","abId":"3bf23dcf","expId":"Voice Azure Test"},"voiceWebsocketUrl":{"value":"wss://voice.flipkart.net/1/speech/ws/join","abId":"3bf23dcf","expId":"Voice Azure Test"},"homep-homep-ecfdf":{"value":"mgdab-homep-f24b3","abId":"3c53448d","expId":"MGDAB 15thJuly 2022"},"homep-homep-7bb3a":{"value":"testh-homep-ba183","abId":"3c53448d","expId":"MGDAB 15thJuly 2022"},"enableLifestyleProductImageSSR":{"value":false,"abId":"3df75aeb","expId":"Desktop Product SSR Control"},"shopsy_rankingBucket":{"value":"shopsy_rpi_AB_27_July","abId":"4ccae6cd","expId":"shopsy_rpi_AB_27_July"},"pinningRuleAbKey":{"value":"reverseABgroceFeedback","abId":"53716ca8","expId":"Grocery Feedback widget"},"sourcerRuleAbKey":{"value":"reverseABgroceFeedback","abId":"53716ca8","expId":"Grocery Feedback widget"},"grocery_feedback":{"value":false,"abId":"53716ca8","expId":"Grocery Feedback widget"},"Header.X-PCD-CART-EXP-1":{"value":false,"abId":"89748a74","expId":"Gh | Control - 12th May"},"cartt-dynam-037fb":{"value":false,"abId":"89748a74","expId":"Gh | Control - 12th May"},"showMoreOffersToNewUsers":{"value":true,"abId":"89748a74","expId":"Gh | Control - 12th May"},"rankingBucket":{"value":"Affluence_RPI_v2","abId":"98b66350","expId":"Affluence_RPI_v2_exp"},"kevlarModeInAB":{"value":"INACTIVE","abId":"STG|targetingGate","expId":"msite_kevlar_filter_shadow"},"kevlarAbEnabled":{"value":true,"abId":"STG|35RDF48XfJySdFmp0pzQ84","expId":"kevlar_session_filter_sanity_experiment"},"kevlarAbMode":{"value":"ACTIVE","abId":"STG|35RDF48XfJySdFmp0pzQ84","expId":"kevlar_session_filter_sanity_experiment"},"super-dynam-0517b":{"value":"super-dynam-0517b","abId":"STG|default","expId":""},"testVar":{"value":"control","abId":"STG|default","expId":""},"disco-dynam-cbb72":{"value":"disco-dynam-cbb72","abId":"STG|default","expId":""},"super-dynam-35f69":{"value":"super-dynam-35f69","abId":"STG|default","expId":""},"clone-dynam-1c690":{"value":"clone-dynam-1c690","abId":"STG|default","expId":""},"super-dynam-2ae24":{"value":"super-dynam-2ae24","abId":"STG|default","expId":""},"clone-dynam-84f57":{"value":"clone-dynam-84f57","abId":"STG|default","expId":""},"clone-dynam-c5465":{"value":"clone-dynam-c5465","abId":"STG|default","expId":""},"super-dynam-70d21":{"value":"super-dynam-70d21","abId":"STG|default","expId":""},"super-dynam-ed52e":{"value":"super-dynam-ed52e"," ...
# <link data-chunk="SearchFeedback" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/SearchFeedback.chunk.cf156a.css" rel="stylesheet"/> <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[118,189]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["NavMenu","SearchFeedback"]}</script>
# <script async="" data-chunk="NavMenu" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/NavMenu.chunk.9a33a3dd.js"></script>
# <script async="" data-chunk="SearchFeedback" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/SearchFeedback.chunk.7599001b.js"></script><script nonce="11285717659153663253">window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;</script><script nonce="11285717659153663253">if ('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") === -1) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 			navigator.onLine && navigator.serviceWorker.controller && navigator.serviceWorker.controller.postMessage('BANDWIDTH_COMPUTE');
# 			navigator.serviceWorker.addEventListener('message', function (event) {
# 				try {
# 					const bandwidthData = JSON.parse(event.data);
# 					if (bandwidthData && bandwidthData.data) {
# 						window.bandwidth = bandwidthData.data.downlink + '_' + bandwidthData.data.computeMethod + '_' + bandwidthData.data.effectiveType + '_' + bandwidthData.data.type;
# 					}
# 				}catch(err) {
# 					console.error('JSON.parse failed:', err);
# 				}
# 			});
# 		})
# 		.catch(function(err) {
# 			console.error('ServiceWorker registration failed: ', err);
# 		});
# 	} else if('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") > -1){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }</script><script nonce="11285717659153663253" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/raven.3.22.3.js"></script><script nonce="11285717659153663253">window.Raven && window.Raven.config('https://b2fe488e344a47eda53b8d306edec9b7@sentry.flipkart.com/2',{
# 		release: '4.104.1',
# 		whitelistUrls: [
# 			/flipkart\.com/,
# 			/flixcart\.com/
# 		],
# 		ignoreErrors: [
# 			// Random plugins/extensions
# 			'top.GLOBALS',
# 			// See: http://blog.errorception.com/2012/03/tale-of-unfindable-js-error.html
# 			'originalCreateNotification',
# 			'canvas.contentDocument',
# 			'MyApp_RemoveAllHighlights',
# 			'atomicFindClose',
# 			// Facebook borked
# 			'fb_xd_fragment',
# 			// ISP "optimizing" proxy - `Cache-Control: no-transform` seems to reduce this. (thanks @acdha)
# 			// See http://stackoverflow.com/questions/4113268/how-to-stop-javascript-injection-from-vodafone-proxy
# 			'bmi_SafeAddOnload',
# 			'EBCallBackMessageReceived',
# 			'failed to fetch'
# 		],
# 		ignoreUrls: [
# 			// Facebook flakiness
# 			/graph\.facebook\.com/i,
# 			// Facebook blocked
# 			/connect\.facebook\.net\/en_US\/all\.js/i,
# 			// Chrome extensions
# 			/extensions\//i,
# 			/^chrome:\/\//i
# 		],
# 		sanitizeKeys: ['nsid', 'secureToken', 'SN'],
# 		environment: 'production',
# 		sampleRate: 0.5
# 	}).install();
# 	window.Raven && window.Raven.setUserContext({
# 		accountId: ''
# 	});</script><script async="" defer="defer" id="omni_script" nonce="11285717659153663253" src="//static-assets-web.flixcart.com/www/linchpin/batman-returns/omni/omni16.js"></script> <script nonce="11285717659153663253">window._pxAppId = 'PXgNtTli3A';</script><script async="" nonce="11285717659153663253" src="//static-assets-web.flixcart.com/px/gNtTli3A/init.js"></script></body></html>

# %%
soup.find_all('div', attrs={'class' : "_4rR01T"})
# Out:
# [<div class="_4rR01T">POCO C31 (Royal Blue, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Blue, 64 GB)</div>,
#  <div class="_4rR01T">POCO C31 (Royal Blue, 32 GB)</div>,
#  <div class="_4rR01T">POCO C31 (Shadow Gray, 64 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Horizon Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme 9 (Sunburst Gold, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Black, 64 GB)</div>,
#  <div class="_4rR01T">realme C31 (Dark Green, 32 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Blue, 32 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Grey, 32 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Daylight Green, 64 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Racing Black, 64 GB)</div>,
#  <div class="_4rR01T">vivo T1X (Gravity Black, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)</div>,
#  <div class="_4rR01T">vivo T1X (Gravity Black, 64 GB)</div>,
#  <div class="_4rR01T">vivo T1X (Space Blue, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)</div>,
#  <div class="_4rR01T">realme C31 (Dark Green, 64 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Grey, 64 GB)</div>,
#  <div class="_4rR01T">realme C31 (Light Silver, 32 GB)</div>,
#  <div class="_4rR01T">REDMI 9i Sport (Coral Green, 64 GB)</div>,
#  <div class="_4rR01T">REDMI Note 10T 5G (Mint Green, 128 GB)</div>]

# %%
soup.find_all('div', attrs={'class': '_1_WHN1'})
# Out:
# [<div class="_30jeq3 _1_WHN1">₹7,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,799</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>]

# %%
soup.find_all('div', attrs={'class': '_3LWZlK'})
# Out:
# [<div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>]

# %%
for x in soup.find_all('div', attrs={'class' : "_4rR01T"}):
    print(x.text)
# Out:
# POCO C31 (Royal Blue, 64 GB)
# SAMSUNG Galaxy F22 (Denim Blue, 64 GB)
# POCO C31 (Royal Blue, 32 GB)
# POCO C31 (Shadow Gray, 64 GB)
# Infinix HOT 12 Play (Horizon Blue, 64 GB)
# realme 9 (Sunburst Gold, 128 GB)
# SAMSUNG Galaxy F22 (Denim Black, 64 GB)
# realme C31 (Dark Green, 32 GB)
# realme C11 2021 (Cool Blue, 32 GB)
# realme C11 2021 (Cool Grey, 32 GB)
# SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)
# Infinix HOT 12 Play (Daylight Green, 64 GB)
# Infinix HOT 12 Play (Racing Black, 64 GB)
# vivo T1X (Gravity Black, 128 GB)
# SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)
# vivo T1X (Gravity Black, 64 GB)
# vivo T1X (Space Blue, 128 GB)
# SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)
# realme C31 (Dark Green, 64 GB)
# realme C11 2021 (Cool Blue, 64 GB)
# realme C11 2021 (Cool Grey, 64 GB)
# realme C31 (Light Silver, 32 GB)
# REDMI 9i Sport (Coral Green, 64 GB)
# REDMI Note 10T 5G (Mint Green, 128 GB)

# %%
for x in soup.find_all('div', attrs={'class' : "_1_WHN1"}):
    print(x.text)
# Out:
# ₹7,999
# ₹10,499
# ₹6,999
# ₹7,999
# ₹8,499
# ₹17,499
# ₹10,499
# ₹8,599
# ₹7,499
# ₹7,499
# ₹11,999
# ₹8,499
# ₹8,499
# ₹14,999
# ₹11,999
# ₹11,999
# ₹14,999
# ₹11,999
# ₹9,999
# ₹8,999
# ₹8,999
# ₹8,599
# ₹8,799
# ₹13,999

# %%
for x in soup.find_all('div' , attrs={'class':'_3LWZlK'}):
    print(x.text)
# Out:
# 4.4
# 4.3
# 4.4
# 4.4
# 4.3
# 4.4
# 4.3
# 4.6
# 4.4
# 4.4
# 4.3
# 4.3
# 4.3
# 5
# 4.3
# 4.6
# 5
# 4.3
# 4.4
# 4.3
# 4.3
# 4.6
# 4.4
# 4.3

# %% [markdown]
# ### productname, price ,specifications ,ratings ,pagenum

# %%
productname=[]
price=[]
specifications=[]
rating=[]
pagenum=[]



for i in range(1,51):
    start_time = time.time()
    url = 'https://www.flipkart.com/search?q=mobiles&otracker=AS_Query_HistoryAutoSuggest_2_0&otracker1=AS_Query_HistoryAutoSuggest_2_0&marketplace=FLIPKART&as-show=on&as=off&as-pos=2&as-type=HISTORY&p%5B%5D=facets.price_range.from%3DMin&p%5B%5D=facets.price_range.to%3D50000&p%5B%5D=facets.brand%255B%255D%3Drealme&p%5B%5D=facets.brand%255B%255D%3DPOCO&p%5B%5D=facets.brand%255B%255D%3DInfinix&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DMi&p%5B%5D=facets.brand%255B%255D%3DBlackBerry&p%5B%5D=facets.brand%255B%255D%3DCelkon&p%5B%5D=facets.brand%255B%255D%3DDELL&p%5B%5D=facets.brand%255B%255D%3DGIVA&p%5B%5D=facets.brand%255B%255D%3DHonor&p%5B%5D=facets.brand%255B%255D%3DHTC&p%5B%5D=facets.brand%255B%255D%3DHP&p%5B%5D=facets.brand%255B%255D%3DHuawei&p%5B%5D=facets.brand%255B%255D%3Diball&p%5B%5D=facets.brand%255B%255D%3DINOVU&p%5B%5D=facets.brand%255B%255D%3DInfocus&p%5B%5D=facets.brand%255B%255D%3DIntex&p%5B%5D=facets.brand%255B%255D%3DItel&p%5B%5D=facets.brand%255B%255D%3DKARBONN&p%5B%5D=facets.brand%255B%255D%3DLAVA&p%5B%5D=facets.brand%255B%255D%3DLenovo&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DMICROSOFT&p%5B%5D=facets.brand%255B%255D%3DMOTOROLA&p%5B%5D=facets.brand%255B%255D%3DPHILIPS&p%5B%5D=facets.brand%255B%255D%3DPanasonic&p%5B%5D=facets.brand%255B%255D%3DREDMI&p%5B%5D=facets.brand%255B%255D%3DSONY&p%5B%5D=facets.brand%255B%255D%3DSony%2BEricsson&p%5B%5D=facets.brand%255B%255D%3Dvivo&p%5B%5D=facets.brand%255B%255D%3DVodafone&p%5B%5D=facets.brand%255B%255D%3DZen&page={}'.format(i)
    page = requests.get(url)
    pagecontent = page.text
    soup = BeautifulSoup(pagecontent)
    
    for x in soup.find_all('div', attrs={'class': '_2kHMtA'}):
        pname = x.find('div', attrs={'class' : "_4rR01T"})
        cost = x.find('div', attrs={'class' : "_1_WHN1"})
        features = x.find('ul' , attrs={'class':'_1xgFaf'})
        ratng = x.find('div' , attrs={'class':'_3LWZlK'})
        
        
        if pname is None:
            productname.append(np.NaN)
        else:
            productname.append(pname.text)
        
        if cost is None:
            price.append(np.NaN)
        else:
            price.append(cost.text)
        
        if features is None:
            specifications.append(np.NaN)
        else:
            specifications.append(features.text)
        
        if ratng is None:
            rating.append(np.NaN)
        else:
            rating.append(ratng.text)
        
        pagenum.append(i)

    print('Page {} completed in {} seconds'.format(i, time.time() -  start_time))
# Out:
# Page 1 completed in 0.9799239635467529 seconds
# Page 2 completed in 1.2190601825714111 seconds
# Page 3 completed in 0.8323707580566406 seconds
# Page 4 completed in 1.029771089553833 seconds
# Page 5 completed in 0.6959958076477051 seconds
# Page 6 completed in 0.8416991233825684 seconds
# Page 7 completed in 0.7230024337768555 seconds
# Page 8 completed in 0.6776854991912842 seconds
# Page 9 completed in 0.941687822341919 seconds
# Page 10 completed in 1.8669953346252441 seconds
# Page 11 completed in 0.8100991249084473 seconds
# Page 12 completed in 0.6909124851226807 seconds
# Page 13 completed in 0.8352818489074707 seconds
# Page 14 completed in 0.6904032230377197 seconds
# Page 15 completed in 0.7823152542114258 seconds
# Page 16 completed in 0.8589868545532227 seconds
# Page 17 completed in 0.895451545715332 seconds
# Page 18 completed in 0.7928571701049805 seconds
# Page 19 completed in 0.588512659072876 seconds
# Page 20 completed in 0.7072172164916992 seconds
# Page 21 completed in 0.6152470111846924 seconds
# Page 22 completed in 0.591158390045166 seconds
# Page 23 completed in 0.6288087368011475 seconds
# Page 24 completed in 0.6574056148529053 seconds
# Page 25 completed in 2.0454866886138916 seconds
# Page 26 completed in 0.5771362781524658 seconds
# Page 27 completed in 0.647824764251709 seconds
# Page 28 completed in 0.7523009777069092 seconds
# Page 29 completed in 0.6698057651519775 seconds
# Page 30 completed in 0.7407314777374268 seconds
# Page 31 completed in 0.6482977867126465 seconds
# Page 32 completed in 0.5907535552978516 seconds
# Page 33 completed in 0.6486883163452148 seconds
# Page 34 completed in 0.6137955188751221 seconds
# Page 35 completed in 0.6443543434143066 seconds
# Page 36 completed in 0.6974451541900635 seconds
# Page 37 completed in 0.7226595878601074 seconds
# Page 38 completed in 0.8213708400726318 seconds
# Page 39 completed in 0.630295991897583 seconds
# Page 40 completed in 0.6494770050048828 seconds
# Page 41 completed in 0.5949463844299316 seconds
# Page 42 completed in 0.3439943790435791 seconds
# Page 43 completed in 0.995736837387085 seconds
# Page 44 completed in 0.43187975883483887 seconds
# Page 45 completed in 0.5964665412902832 seconds
# Page 46 completed in 0.5326297283172607 seconds
# Page 47 completed in 0.6324148178100586 seconds
# Page 48 completed in 0.5551965236663818 seconds
# Page 49 completed in 0.5177342891693115 seconds
# Page 50 completed in 0.39094972610473633 seconds

# %%
len(productname)
# Out:
# 984

# %%
mobile_df = pd.DataFrame({'productname':productname , 'price': price , 'specifications': specifications , 'rating':rating , 'pagenumber': pagenum})

# %%
mobile_df.head()
# Out:
#                                  productname    price  \
# 0               POCO C31 (Royal Blue, 64 GB)   ₹7,999
# 1              POCO C31 (Shadow Gray, 64 GB)   ₹7,999
# 2               POCO C31 (Royal Blue, 32 GB)   ₹6,999
# 3     SAMSUNG Galaxy F22 (Denim Blue, 64 GB)  ₹10,499
# 4  Infinix HOT 12 Play (Horizon Blue, 64 GB)   ₹8,499
#
#                                       specifications rating  pagenumber
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...    4.4           1
# 1  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...    4.4           1
# 2  3 GB RAM | 32 GB ROM | Expandable Upto 512 GB1...    4.4           1
# 3  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....    4.3           1
# 4  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.3           1

# %%
mobile_df['productname'].unique()
# Out:
# array(['POCO C31 (Royal Blue, 64 GB)', 'POCO C31 (Shadow Gray, 64 GB)',
#        'POCO C31 (Royal Blue, 32 GB)',
#        'SAMSUNG Galaxy F22 (Denim Blue, 64 GB)',
#        'Infinix HOT 12 Play (Horizon Blue, 64 GB)',
#        'realme 9 (Sunburst Gold, 128 GB)',
#        'SAMSUNG Galaxy F22 (Denim Black, 64 GB)',
#        'realme C11 2021 (Cool Blue, 32 GB)',
#        'realme C11 2021 (Cool Grey, 32 GB)',
#        'SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)',
#        'realme C31 (Dark Green, 32 GB)',
#        'Infinix HOT 12 Play (Racing Black, 64 GB)',
#        'Infinix HOT 12 Play (Daylight Green, 64 GB)',
#        'SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)',
#        'vivo T1X (Gravity Black, 64 GB)',
#        'vivo T1X (Gravity Black, 128 GB)',
#        'vivo T1X (Space Blue, 128 GB)',
#        'SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)',
#        'realme C11 2021 (Cool Blue, 64 GB)',
#        'realme C11 2021 (Cool Grey, 64 GB)',
#        'realme C31 (Dark Green, 64 GB)',
#        'realme C31 (Light Silver, 32 GB)',
#        'REDMI 9i Sport (Coral Green, 64 GB)',
#        'REDMI Note 10T 5G (Mint Green, 128 GB)',
#        'POCO M4 Pro (Power Black, 64 GB)',
#        'realme C31 (Light Silver, 64 GB)',
#        'realme 9 (Stargaze White, 128 GB)',
#        'POCO M4 5G (Cool Blue, 64 GB)', 'POCO M4 5G (Power Black, 64 GB)',
#        'POCO M4 Pro (Cool Blue, 64 GB)',
#        'Infinix Hot 11 2022 (Sunset Gold, 64 GB)',
#        'REDMI 9i Sport (Metallic Blue, 64 GB)',
#        'Infinix Note 12 (Force Black, 64 GB)',
#        'Infinix Note 12 (Jewel Blue, 64 GB)',
#        'realme Narzo 50i (Carbon Black, 64 GB)',
#        'REDMI Note 10T 5G (Metallic Blue, 64 GB)',
#        'REDMI 10 (Pacific Blue, 64 GB)',
#        'realme 8s 5G (Universe Purple, 128 GB)',
#        'REDMI Note 10 Pro (Vintage Bronze, 128 GB)',
#        'SAMSUNG Galaxy F22 (Denim Blue, 128 GB)',
#        'realme Narzo 50i (Mint Green, 64 GB)',
#        'REDMI 10 (Caribbean Green, 64 GB)',
#        'realme Narzo 50A (Oxygen Green, 64 GB)',
#        'MOTOROLA g31 (Baby Blue, 64 GB)',
#        'REDMI 10 (Midnight Black, 64 GB)', 'POCO M4 Pro (Yellow, 64 GB)',
#        'realme C21Y (Cross Blue, 32 GB)',
#        'realme C21Y (Cross Blue, 64 GB)',
#        'realme C21Y (Cross Black, 32 GB)',
#        'REDMI Note 10T 5G (Graphite Black, 128 GB)',
#        'vivo T1 5G (Starlight Black, 128 GB)',
#        'vivo T1 5G (Rainbow Fantasy, 128 GB)',
#        'SAMSUNG Galaxy F22 (Denim Black, 128 GB)',
#        'POCO M4 5G (Yellow, 64 GB)', 'vivo T1 44W (Ice Dawn, 128 GB)',
#        'vivo T1 44W (Midnight Galaxy, 128 GB)',
#        'vivo T1 44W (Starry Sky, 128 GB)',
#        'REDMI Note 10S (Deep Sea Blue, 64 GB)',
#        'MOTOROLA G60 (Soft Silver, 128 GB)',
#        'REDMI 9i Sport (Carbon Black, 64 GB)',
#        'realme Narzo 50A (Oxygen Green, 128 GB)',
#        'realme Narzo 50A (Oxygen Blue, 128 GB)',
#        'POCO M4 5G (Cool Blue, 128 GB)',
#        'Infinix Hot 11 2022 (Aurora Green, 64 GB)',
#        'POCO M4 Pro (Cool Blue, 128 GB)',
#        'realme C21Y (Cross Black, 64 GB)',
#        'realme 8s 5G (Universe Blue, 128 GB)',
#        'realme 9i (Prism Blue, 128 GB)',
#        'realme 9i (Prism Black, 128 GB)',
#        'REDMI Note 10S (Cosmic Purple, 64 GB)',
#        'POCO C31 (Shadow Gray, 32 GB)',
#        'SAMSUNG Galaxy M33 5G (Deep Ocean Blue, 128 GB)',
#        'POCO M4 Pro (Power Black, 128 GB)',
#        'vivo Y53s (Fantastic Rainbow, 128 GB)',
#        'vivo Y53s (Deep Sea Blue, 128 GB)',
#        'REDMI Note 10 Pro (Dark Night, 128 GB)',
#        'realme 9 (Meteor Black, 128 GB)',
#        'realme 9i (Prism Black, 64 GB)', 'POCO M4 Pro (Yellow, 128 GB)',
#        'realme Narzo 50A (Oxygen Blue, 64 GB)',
#        'REDMI Note 10S (Frost White, 64 GB)',
#        'POCO M4 Pro 5G (Power Black, 64 GB)',
#        'SAMSUNG Galaxy M33 5G (Mystique Green, 128 GB)',
#        'Infinix Note 12 (Force Black, 128 GB)',
#        'Infinix Note 12 (Jewel Blue, 128 GB)',
#        'MOTOROLA g31 (Meteorite Grey, 64 GB)',
#        'POCO M4 Pro 5G (Cool Blue, 128 GB)',
#        'realme C35 (Glowing Green, 64 GB)',
#        'MOTOROLA G60 (Moonless, 128 GB)',
#        'Infinix Hot 11 2022 (Polar Black, 64 GB)',
#        'realme C35 (Glowing Black, 64 GB)',
#        'POCO X4 Pro 5G (Laser Blue, 128 GB)',
#        'REDMI Note 10T 5G (Chromium White, 128 GB)',
#        'MOTOROLA g52 (Charcoal Grey, 128 GB)',
#        'REDMI 9i (Midnight Black, 64 GB)',
#        'realme Narzo 50i (Carbon Black, 32 GB)',
#        'realme Narzo 50i (Mint Green, 32 GB)',
#        'Moto G71 5G (Neptune Green, 128 GB)',
#        'POCO M4 Pro 5G (Cool Blue, 64 GB)',
#        'realme Narzo 50 (Speed Blue, 64 GB)',
#        'POCO M4 5G (Power Black, 128 GB)',
#        'Infinix Hot 11S (Polar Black, 64 GB)',
#        'REDMI 10 (Pacific Blue, 128 GB)',
#        'realme Narzo 30 5G (Racing Blue, 64 GB)',
#        'realme C35 (Glowing Green, 128 GB)',
#        'realme 9 Pro 5G (Sunrise Blue, 128 GB)',
#        'MOTOROLA g52 (Metallic White, 128 GB)',
#        'POCO M4 Pro 5G (Power Black, 128 GB)',
#        'Infinix Smart 6 (Starry Purple, 64 GB)',
#        'Infinix Smart 6 (Heart Of Ocean, 64 GB)',
#        'REDMI 10 PRIME 2022 (Bifrost Blue, 64 GB)',
#        'POCO X4 Pro 5G (Laser Black, 128 GB)',
#        'Moto G71 5G (Arctic Blue, 128 GB)',
#        'realme Narzo 50 (Speed Blue, 128 GB)',
#        'MOTOROLA g22 (Iceberg Blue, 64 GB)',
#        'MOTOROLA G40 Fusion (Dynamic Gray, 128 GB)',
#        'REDMI Note 10T 5G (Chromium White, 64 GB)',
#        'realme Narzo 30 5G (Racing Blue, 128 GB)',
#        'REDMI Note 10 Pro Max (Dark Night, 128 GB)',
#        'Infinix Smart 6 (Light Sea Green, 64 GB)',
#        'Redmi 9A Sport (Carbon Black, 32 GB)',
#        'Redmi 9A Sport (Metallic Blue, 32 GB)',
#        'MOTOROLA g52 (Charcoal Grey, 64 GB)',
#        'REDMI 10 Prime (Phantom Black, 64 GB)',
#        'Infinix Hot 11S (Green Wave, 64 GB)',
#        'Infinix Hot 11S (7° Purple, 64 GB)',
#        'realme Narzo 50 (Speed Black, 64 GB)',
#        'MOTOROLA g31 (Baby Blue, 128 GB)',
#        'Infinix Note 12 Pro 5G (Force Black, 128 GB)',
#        'POCO M4 Pro 5G (Yellow, 128 GB)',
#        'REDMI 10A (Charcoal Black, 32 GB)',
#        'SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)',
#        'POCO M3 Pro 5G (Yellow, 64 GB)',
#        'realme Narzo 50 (Speed Black, 128 GB)',
#        'MOTOROLA g31 (Meteorite Grey, 128 GB)',
#        'REDMI 10 (Caribbean Green, 128 GB)',
#        'Redmi 9A Sport (Coral Green, 32 GB)',
#        'MOTOROLA G51 5G (Indigo Blue, 64 GB)',
#        'Infinix Smart 5A (Quetzal Cyan, 32 GB)',
#        'Infinix Smart 5A (Ocean Wave, 32 GB)',
#        'Infinix Smart 5A (Midnight Black, 32 GB)',
#        'realme Narzo 30 5G (Racing Silver, 128 GB)',
#        'REDMI Note 10 Pro Max (Dark Nebula, 128 GB)',
#        'realme C35 (Glowing Black, 128 GB)',
#        'MOTOROLA Edge 20 Fusion 5G (Electric Graphite, 128 GB)',
#        'REDMI Note 10T 5G (Mint Green, 64 GB)',
#        'POCO M4 Pro 5G (Yellow, 64 GB)',
#        'REDMI 10 (Midnight Black, 128 GB)',
#        'MOTOROLA G51 5G (Bright Silver, 64 GB)',
#        'REDMI 9 Activ (Carbon Black, 128 GB)',
#        'Redmi Note 11 (Starburst White, 64 GB)',
#        'REDMI Note 11T 5G (Matte black, 128 GB)',
#        'REDMI Note 11T 5G (Aquamarine Blue, 128 GB)',
#        'SAMSUNG Galaxy M12 (Black, 128 GB)',
#        'REDMI 9 Activ (Coral Green, 128 GB)',
#        'SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)',
#        'SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)',
#        'Infinix Note 12 Pro 5G (Snowfall, 128 GB)',
#        'POCO X4 Pro 5G (Yellow, 128 GB)', 'realme 9i (Prism Blue, 64 GB)',
#        'LAVA A1 Josh 2021', 'REDMI 10 Prime 2022 (Bifrost Blue, 64 GB)',
#        'MOTOROLA G40 Fusion (Frosted Champagne, 128 GB)',
#        'REDMI 10 Prime 2022 (Phantom Black, 64 GB)',
#        'MOTOROLA g52 (Metallic White, 64 GB)',
#        'SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)',
#        'REDMI 10A (Sea Blue, 64 GB)',
#        'SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)', 'LAVA A3',
#        'Itel Magic2 4G (WiFi, Hotspot Tethering)',
#        'MOTOROLA e40 (Carbon Gray, 64 GB)',
#        'Itel Magic2 4G( WiFi,Hotspot Tethering)',
#        'REDMI Note 10T 5G (Graphite Black, 64 GB)',
#        'POCO M4 5G (Yellow, 128 GB)',
#        'REDMI Note 10 Pro Max (Vintage Bronze, 128 GB)',
#        'REDMI Note 10S (Deep Sea Blue, 128 GB)',
#        'Infinix Note 12 5G (Snowfall, 64 GB)',
#        'Infinix Note 12 5G (Force Black, 64 GB)',
#        'POCO M3 Pro 5G (Cool Blue, 128 GB)',
#        'POCO M3 Pro 5G (Power Black, 64 GB)',
#        'MOTOROLA g22 (Mint Green, 64 GB)', 'LAVA GEM',
#        'Infinix Smart 6 (Polar Black, 64 GB)',
#        'realme 9 Pro+ 5G (Midnight Black, 128 GB)',
#        'realme 9 Pro+ 5G (Sunrise Blue, 128 GB)',
#        'realme 9 Pro 5G (Midnight Black, 128 GB)',
#        'realme 9 Pro 5G (Aurora Green, 128 GB)',
#        'POCO F4 5G (Night Black, 128 GB)',
#        'POCO M3 Pro 5G (Cool Blue, 64 GB)',
#        'POCO F4 5G (Nebula Green, 128 GB)',
#        'REDMI 10 Prime (Bifrost Blue, 128 GB)',
#        'realme 9 Pro+ 5G (Aurora Green, 128 GB)',
#        'SAMSUNG Galaxy M12 (Blue, 128 GB)',
#        'SAMSUNG Galaxy M52 5G (Icy Blue, 128 GB)',
#        'SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)',
#        'SAMSUNG Galaxy M33 5G (Emarld Brown, 128 GB)',
#        'POCO M3 Pro 5G (Power Black, 128 GB)',
#        'vivo Y15s (Mystic Blue, 32 GB)', 'Itel IT2163',
#        'POCO M2 (Pitch Black, 64 GB)',
#        'MOTOROLA Edge 30 (Meteor Grey, 128 GB)', 'LAVA A3 Power',
#        'REDMI 10A (Slate Grey, 32 GB)', 'realme C30 (Lake Blue, 32 GB)',
#        'REDMI Note 10 Pro (Glacial Blue, 128 GB)',
#        'realme C20 (Cool Grey, 32 GB)',
#        'REDMI 9 Prime (Sunrise Flare, 64 GB)', 'LAVA Hero Punch',
#        'SAMSUNG Galaxy M12 (White, 64 GB)',
#        'REDMI Note 10 Pro (Dark Nebula, 128 GB)',
#        'POCO X4 Pro 5G (Laser Black, 64 GB)',
#        'MOTOROLA g42 (Atlantic Green, 64 GB)',
#        'Xiaomi 11i 5G (Purple Mist, 128 GB)',
#        'vivo Y15c (Wave Green, 32 GB)',
#        'realme 9 Pro+ 5G (Sunrise Blue, 256 GB)',
#        'realme C30 (Bamboo Green, 32 GB)',
#        'POCO X4 Pro 5G (Yellow, 64 GB)', 'LAVA A1 2021',
#        'realme C20 (Cool Blue, 32 GB)',
#        'Infinix Note 12 TURBO (Force Black, 128 GB)',
#        'POCO F4 5G (Night Black, 256 GB)',
#        'Infinix Note 12 TURBO (Jewel Blue, 128 GB)',
#        'Infinix Note 12 TURBO (Snowfall, 128 GB)',
#        'MOTOROLA e40 (Pink Clay, 64 GB)', 'Motorola a10',
#        'POCO X4 Pro 5G (Laser Blue, 64 GB)',
#        'realme C30 (Denim Black, 32 GB)',
#        'vivo T1 Pro 5G (Turbo Black, 128 GB)', 'LAVA Hero 600+',
#        'realme 9 Pro+ 5G (Midnight Black, 256 GB)',
#        'vivo Y75 5G (Starlight Black, 128 GB)',
#        'Redmi Note 11 (Horizon Blue, 64 GB)',
#        'SAMSUNG Galaxy M12 (Black, 64 GB)',
#        'vivo Y33T (Mirror Black, 128 GB)',
#        'vivo Y33T (Mid day dream, 128 GB)',
#        'REDMI 9 Activ (Metallic Purple, 128 GB)',
#        'REDMI 9 Activ (Carbon Black, 64 GB)',
#        'REDMI 9 Activ (Metallic Purple, 64 GB)',
#        'REDMI 9 Activ (Coral Green, 64 GB)',
#        'POCO F4 5G (Nebula Green, 256 GB)',
#        'MOTOROLA Edge 20 Fusion 5G (Cyber Teal, 128 GB)',
#        'Xiaomi 11i 5G (Stealth Black, 128 GB)',
#        'vivo Y21G (Diamond Glow, 64 GB)',
#        'MOTOROLA Edge 30 (Aurora Green, 128 GB)',
#        'REDMI Note 10S (Frost White, 128 GB)',
#        'SAMSUNG Galaxy M32 (Light Blue, 128 GB)',
#        'SAMSUNG Galaxy F12 (Sky Blue, 64 GB)',
#        'REDMI Note 10T 5G (Metallic Blue, 128 GB)', 'Itel It2171',
#        'Xiaomi 11i 5G (Pacific Pearl, 128 GB)',
#        'vivo Y75 5G (Glowing Galaxy, 128 GB)',
#        'realme 9 5G (Supersonic Blue, 64 GB)',
#        'REDMI 10 Prime (Phantom Black, 128 GB)',
#        'MOTOROLA Edge 20 5G (Frosted Onyx, 128 GB)',
#        'REDMI Note 11S (Space Black, 64 GB)',
#        'REDMI Note 11S (Space Black, 128 GB)',
#        'REDMI Note 11S (Horizon Blue, 128 GB)',
#        'MOTOROLA g82 5G(White Lily, 128 GB)',
#        'realme 9 Pro+ 5G (Aurora Green, 256 GB)',
#        'Redmi 9A (Nature Green, 32 GB)',
#        'REDMI 10 Power (Power Black, 128 GB)',
#        'REDMI 10A (Charcoal Black, 64 GB)', 'Itel Ace',
#        'vivo T1 Pro 5G (Turbo Cyan, 128 GB)', 'KARBONN K9 max',
#        'realme 9 5G (Supersonic Black, 64 GB)',
#        'realme 9 5G (Meteor Black, 64 GB)',
#        'realme 9 5G (Stargaze White, 64 GB)',
#        'realme 9 5G (Meteor Black, 128 GB)',
#        'realme Narzo 30 (Racing Silver, 64 GB)',
#        'POCO M3 Pro 5G (Yellow, 128 GB)',
#        'vivo Y21G (Midnight Blue, 64 GB)', 'Redmi 9A (SeaBlue, 32 GB)',
#        'SAMSUNG Galaxy F12 (Sea Green, 64 GB)',
#        'realme 8i (Space Black, 64 GB)',
#        'Infinix Note 11s (Symphony Cyan, 64 GB)',
#        'REDMI Note 10S (Shadow Black, 64 GB)',
#        'SAMSUNG Galaxy F12 (Celestial Black, 64 GB)',
#        'Infinix Hot 11 (Silver Wave, 64 GB)',
#        'realme C25Y (Metal Grey, 64 GB)',
#        'Infinix Hot 11 (Emerald Green, 64 GB)',
#        'realme 9 5G (Stargaze White, 128 GB)',
#        'realme C25Y (Glacier Blue, 64 GB)', 'KARBONN KX3',
#        'SAMSUNG Galaxy A12 (Black, 64 GB)',
#        'Xiaomi 11i Hypercharge 5G (Camo Green, 128 GB)',
#        'Xiaomi 11i Hypercharge 5G (Pacific Pearl, 128 GB)',
#        'LAVA A1 Super 2021', 'REDMI Note 11T 5G (Stardust White, 64 GB)',
#        'realme 9 5G (Supersonic Black, 128 GB)', 'KARBONN K310i',
#        'Redmi Note 11 (Starburst White, 128 GB)', 'Motorola a70',
#        'Infinix Hot 11S (Green Wave, 128 GB)',
#        'Infinix Hot 11S (7° Purple, 128 GB)',
#        'vivo Y01 (Sapphire Blue, 32 GB)',
#        'REDMI 10 Prime 2022 (Astral White, 64 GB)',
#        'Redmi Note 11 PRO Plus 5G (Stealth Black, 128 GB)',
#        'SAMSUNG Galaxy M12 (Blue, 64 GB)',
#        'realme 8i (Space Black, 128 GB)',
#        'SAMSUNG Galaxy A53 (Awesome Black, 128 GB)',
#        'Xiaomi 11i Hypercharge 5G (Stealth Black, 128 GB)', 'LAVA A1500',
#        'realme Narzo 30 (Racing Blue, 128 GB)',
#        'Redmi Note 11 (Space Black, 128 GB)',
#        'SAMSUNG Galaxy M32 5G (Sky Blue, 128 GB)', 'SAMSUNG Guru Music 2',
#        'Motorola a50', 'SAMSUNG Guru Music 2 SM-B315E',
#        'LAVA Blaze (Glass Green, 64 GB)',
#        'realme C21 (Cross Blue, 32 GB)', 'LAVA A1',
#        'Infinix Hot 11S (Silver Wave, 128 GB)',
#        'vivo Y75 (Dancing waves, 128 GB)',
#        'vivo Y75 (Moonlight Shadow, 128 GB)', 'KARBONN KX 29',
#        'Itel Power 110', 'Infinix Note 11 (Celestial Snow, 128 GB)',
#        'KARBONN KX 10i', 'SAMSUNG Galaxy F12 (Sky Blue, 128 GB)',
#        'SAMSUNG Galaxy M32 (Black, 64 GB)',
#        'Infinix Note 11 (Glacier Green, 128 GB)',
#        'realme C25_Y (Glacier Blue, 64 GB)',
#        'realme C25_Y (Metal Grey, 64 GB)',
#        'vivo V23 5G (Sunshine Gold, 128 GB)',
#        'Infinix Note 11 (Graphite Black, 128 GB)',
#        'SAMSUNG Galaxy A03 Core (Black, 32 GB)',
#        'vivo V23 5G (Stardust Black, 128 GB)',
#        'SAMSUNG Galaxy M32 (Black, 128 GB)',
#        'SAMSUNG Galaxy F12 (Celestial Black, 128 GB)',
#        'realme 9 5G SE (Azure Glow, 128 GB)',
#        'Infinix Note 11s (Mithril Grey, 64 GB)',
#        'realme 9 5G SE (Starry Glow, 128 GB)',
#        'Infinix Note 11s (Haze Green, 64 GB)',
#        'SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)',
#        'SAMSUNG GURU MUSIC 2', 'vivo Y15c (Mystic Blue, 32 GB)',
#        'realme 8 5G (Supersonic Black, 128 GB)',
#        'realme 8 5G (Supersonic Black, 64 GB)',
#        'realme 9 5G (Supersonic Blue, 128 GB)',
#        'realme C21 (Cross Black, 32 GB)', 'Itel it2175',
#        'SAMSUNG Galaxy A22 5G (Gray, 128 GB)',
#        'MOTOROLA g82 5G (Meterorite Grey, 128 GB)',
#        'Infinix Note 11 (Glacier Green, 64 GB)',
#        'REDMI Note 11S (Polar White, 64 GB)',
#        'Xiaomi 11i Hypercharge 5G (Purple Mist, 128 GB)',
#        'Itel Power 400', 'vivo V23 5G (Sunshine Gold, 256 GB)',
#        'SAMSUNG M21 2021 Edition (Charcoal Black, 64 GB)',
#        'REDMI Note 11 Pro (Stealth Black, 128 GB)',
#        'REDMI Note 11 Pro (Phantom White, 128 GB)',
#        'MOTOROLA edge 30 (Aurora Green, 128 GB)',
#        'REDMI Note 10S (Shadow Black, 128 GB)',
#        'SAMSUNG Galaxy A03 Core (Blue, 32 GB)',
#        'Redmi Note 11 PRO Plus 5G (Phantom White, 128 GB)',
#        'Redmi Note 11 PRO Plus 5G (Stealth Black, 256 GB)',
#        'realme C25_Y (Glacier Blue, 128 GB)',
#        'Redmi Note 11 PRO Plus 5G (Mirage Blue, 256 GB)',
#        'realme C25_Y (Metal Grey, 128 GB)', 'SAMSUNG GURU GT',
#        'SAMSUNG S20 FE 5G (Cloud Navy, 128 GB)',
#        'vivo Y21T (Midnight Blue, 128 GB)',
#        'vivo Y21T (Pearl White, 128 GB)',
#        'vivo Y01 (Elegant Black, 32 GB)',
#        'LAVA Z2s (Striped Blue, 32 GB)',
#        'SAMSUNG Galaxy A13 (Blue, 128 GB)',
#        'SAMSUNG Galaxy A03 (Black, 32 GB)', 'Itel U20',
#        'realme Narzo 30 (Racing Silver, 128 GB)',
#        'realme 7 Pro (Mirror Silver, 128 GB)',
#        'SAMSUNG Galaxy F12 (Sea Green, 128 GB)',
#        'SAMSUNG Galaxy A23 (Peach, 128 GB)', 'LAVA Flip',
#        'Itel Power 410', 'Itel Ace Star', 'Itel power 100',
#        'Infinix Note 10 Pro (95° Black, 256 GB)',
#        'REDMI Note 10S (Cosmic Purple, 128 GB)',
#        'Infinix Note 11 (Celestial Snow, 64 GB)',
#        'realme C25s (Watery Grey, 128 GB)',
#        'realme C25s (Watery Blue, 128 GB)',
#        'realme 8 (Cyber Black, 128 GB)', 'POCO C3 (Lime Green, 32 GB)',
#        'realme 8 (Cyber Silver, 128 GB)',
#        'Itel A25 (Gradation Blue, 16 GB)',
#        'SAMSUNG Galaxy A32 (Awesome Black, 128 GB)',
#        'Mi A3 (Not just Blue, 64 GB)', 'KARBONN K8 POWER BLUE',
#        'Infinix Note 11s Free Fire Edition (Haze Green, 128 GB)',
#        'SAMSUNG Galaxy A52 (Awesome Blue, 128 GB)',
#        'Infinix Note 10 Pro (Nordic Secret, 256 GB)',
#        'Infinix Note 11s Free Fire Edition (Mithril Grey, 128 GB)',
#        'Infinix Zero 5G (Cosmic Black, 128 GB)', 'KARBONN K2 Boom Box',
#        'vivo T1X (Space Blue, 64 GB)',
#        'SAMSUNG Galaxy F42 5G (Matte Aqua, 128 GB)', 'KARBONN KX5',
#        'vivo Y12s (Glacier Blue, 32 GB)',
#        'vivo Y21A (Midnight Blue, 64 GB)',
#        'SAMSUNG Galaxy A73 5G (Awesome Mint, 128 GB)',
#        'Infinix Zero 5G (Skylight Orange, 128 GB)',
#        'REDMI Note 9 (Shadow Black, 64 GB)',
#        'Redmi 9A (Midnight Black, 32 GB)',
#        'REDMI 10 Power (Sporty Orange, 128 GB)',
#        'SAMSUNG M21 2021 Edition (Arctic blue, 64 GB)',
#        'SAMSUNG Galaxy A23 (Blue, 128 GB)',
#        'SAMSUNG Galaxy M42 (Prism Dot Gray, 128 GB)',
#        'SAMSUNG Galaxy A73 5G (Awesome Gray, 128 GB)',
#        'Itel Power 100 New', 'KARBONN K9 Yuva',
#        'vivo V21 5G (Neon Spark, 128 GB)',
#        'vivo V21 5G (Sunset Dazzle, 128 GB)',
#        'vivo V21 5G (Dusk Blue, 128 GB)',
#        'LAVA AGNI (Fiery Blue, 128 GB)',
#        'realme C25s (Watery Grey, 64 GB)',
#        'realme GT NEO 2 (NEO Blue, 256 GB)',
#        'SAMSUNG Galaxy M32 5G (Slate Black, 128 GB)', 'KARBONN K8 POWER',
#        'LAVA A5', 'vivo V23e 5G (Midnight Blue, 128 GB)',
#        'SAMSUNG Galaxy A22 5G (Mint, 128 GB)',
#        'vivo Y33s (Mirror Black, 128 GB)',
#        'POCO F3 GT 5G (Gunmetal Silver, 128 GB)',
#        'SAMSUNG Galaxy A73 5G (Awesome White, 128 GB)',
#        'SAMSUNG Galaxy F42 5G (Matte Black, 128 GB)',
#        'Itel A25 (Gradation Green, 16 GB)', 'LAVA A9',
#        'SAMSUNG Galaxy M32 (Light Blue, 64 GB)',
#        'vivo V23e 5G (Sunshine Gold, 128 GB)',
#        'Mi 11 Lite (Vinyl Black, 128 GB)',
#        'Xiaomi 11Lite NE (Jazz Blue, 128 GB)',
#        'SAMSUNG Galaxy A12 (Blue, 128 GB)',
#        'realme 8 5G (Supersonic Blue, 128 GB)',
#        'Infinix Smart 5 (Aegean Blue, 32 GB)',
#        'REDMI Note 11S (Horizon Blue, 64 GB)', 'KARBONN K140 Pop',
#        'SAMSUNG Galaxy A13 (Black, 128 GB)',
#        'vivo Y20G (Obsidian Black, 128 GB)', 'Itel A49 (Sky Cyan, 32 GB)',
#        'Itel A49 (Dome Blue, 32 GB)', 'vivo Y21E (Diamond Glow, 64 GB)',
#        'vivo Y31 (Ocean Blue, 128 GB)',
#        'SAMSUNG M32 5G (Slate Black, 128 GB)', 'Itel IT2173',
#        'SAMSUNG Galaxy A73 5G (Awesome Mint, 256 GB)',
#        'Itel Vision2S (Gradation Blue, 32 GB)',
#        'realme GT 2 (Paper White, 256 GB)',
#        'realme GT 2 (Steel Black, 256 GB)',
#        'vivo Y31 (Racing Black, 128 GB)',
#        'realme C12 (Power Blue, 32 GB)', 'Itel it2163S',
#        'SAMSUNG M32 5G (Sky blue, 128 GB)',
#        'vivo Y33s (Midday Dream, 128 GB)', 'LAVA Spark i8', 'KARBONN K9',
#        'SAMSUNG Metro 313 Dual Sim', 'vivo Y72 5G (Slate Gray, 128 GB)',
#        'PHILIPS E102A',
#        'MOTOROLA Edge 20 Pro 5G (Iridescent Cloud, 128 GB)',
#        'Infinix Zero 5G (Horizon Blue, 128 GB)',
#        'SAMSUNG Galaxy A52 (Awesome Black, 128 GB)',
#        'Xiaomi 11Lite NE (Vinyl Black, 128 GB)',
#        'SAMSUNG Galaxy A12 (Black, 128 GB)',
#        'SAMSUNG Galaxy A23 (Black, 128 GB)',
#        'vivo Y20G 2021 (Obsidian Black, 64 GB)',
#        'realme GT 2 (Paper White, 128 GB)',
#        'realme GT 2 (Paper Green, 128 GB)',
#        'Infinix Hot 10 Play (Morandi Green, 64 GB)',
#        'realme X7 Pro 5G (Mystic Black, 128 GB)',
#        'vivo Y73 (Diamond Flare, 128 GB)', 'Itel it5026',
#        'Xiaomi 11Lite NE (Tuscany Coral, 128 GB)', 'Itel Ace 2N',
#        'vivo Y21A (Diamond Glow, 64 GB)',
#        'REDMI Note 11 Pro (Star Blue, 128 GB)',
#        'Xiaomi 11T Pro 5G Hyperphone (Moonlight White, 128 GB)',
#        'vivo Y72 5G (Prism Magic, 128 GB)',
#        'SAMSUNG Galaxy A03 (Black, 64 GB)',
#        'Redmi Y3 (Prime Black, 32 GB)',
#        'REDMI 9 Prime (Space Blue, 128 GB)', 'Itel Muzik 110',
#        'SAMSUNG Guru 1200', 'Itel Ace Young Without Charger',
#        'Redmi 8 (Ruby Red, 64 GB)', 'Itel Muzik 400 Core', 'LAVA A7 2020',
#        'realme C25Y (Metal Grey, 128 GB)',
#        'SAMSUNG Galaxy A03 (Blue, 64 GB)',
#        'realme GT 5G (Dashing Silver, 128 GB)',
#        'Mi 11 Lite (Jazz Blue, 128 GB)',
#        'realme X7 Max (Mercury Silver, 256 GB)',
#        'SAMSUNG Galaxy A03 (Red, 32 GB)',
#        'realme X7 Max (Asteroid Black, 256 GB)',
#        'vivo Y20G 2021 (Purist Blue, 64 GB)',
#        'POCO M2 Pro (Out of the Blue, 64 GB)',
#        'SAMSUNG Galaxy A52s 5G (Awesome Violet, 128 GB)',
#        'KARBONN K9 Junior', 'KARBONN K9 Mini',
#        'Infinix Hot 10 Play (Obsidian Black, 64 GB)',
#        'SAMSUNG Galaxy M02 (Gray, 32 GB)',
#        'SAMSUNG M53 5G (Mystique Green, 128 GB)', 'LAVA A7 Star',
#        'realme GT Master Edition (Cosmos Black, 256 GB)',
#        'vivo V23 Pro 5G (Stardust Black, 128 GB)',
#        'realme Narzo 30 Pro 5G (Sword Black, 128 GB)',
#        'Infinix Hot 10 (Amber Red, 128 GB)', 'LAVA Hero 1800',
#        'KARBONN KX6', 'Itel A49 (Crystal Purple, 32 GB)', 'LAVA A1 Josh',
#        'Itel Magic 1 Core New', 'vivo Y12s (Phantom Black, 32 GB)',
#        'KARBONN K9 SHAKTI',
#        'realme GT Master Edition (Cosmos Black, 128 GB)',
#        'REDMI Note 9 (Pebble Grey, 64 GB)',
#        'vivo Y21E (Midnight Blue, 64 GB)',
#        'Itel Vision 2 (Deep Blue, 32 GB)',
#        'realme GT Master Edition (Daybreak Blue, 256 GB)', 'KARBONN K531',
#        'Itel A48 (Gradation Black, 32 GB)',
#        'POCO M2 Reloaded (Mostly Blue, 64 GB)',
#        'Xiaomi 11T Pro 5G Hyperphone (Celestial Magic, 128 GB)',
#        'Itel Vision 3 (Multi Green, 64 GB)',
#        'vivo Y3s (Pearl white, 32 GB)',
#        'SAMSUNG Galaxy A33 (Awesome Black, 128 GB)',
#        'SAMSUNG Galaxy A13 (Black, 64 GB)',
#        'Redmi 9 (Sporty Orange, 64 GB)',
#        'REDMI NOTE 10 LITE (Champagne Gold, 64 GB)', 'Itel Magic2',
#        'Mi 11X (Lunar White, 128 GB)', 'Mi 11X (Cosmic Black, 128 GB)',
#        'POCO C3 (Lime Green, 64 GB)',
#        'POCO M2 Pro (Green and Greener, 64 GB)',
#        'Itel Vision 3 (Jewel Blue, 64 GB)',
#        'realme Narzo 30 Pro 5G (Blade Silver, 128 GB)',
#        'REDMI Note 10 (Shadow Black, 128 GB)', 'LAVA Gem Wave / GEM',
#        'Infocus Hero 1', 'Redmi 8A (Midnight Black, 32 GB)',
#        'realme GT NEO 2 (NEO Black, 256 GB)', 'PHILIPS Xenium E209',
#        'SAMSUNG GT-E1215ZWAINS', 'SAMSUNG Guru FM Plus SM-B110E/D',
#        'vivo Y21 (Midnight Blue, 64 GB)', 'realme X7 5G (Nebula, 128 GB)',
#        'KARBONN Y1', 'Redmi Note 9 Pro (Interstellar Black, 64 GB)',
#        'Xiaomi 11i 5G (Camo Green, 128 GB)',
#        'SAMSUNG Galaxy A53 (Awesome Blue, 128 GB)',
#        'realme Narzo 20 (Victory Blue, 64 GB)',
#        'realme C25Y (Glacier Blue, 128 GB)', 'LG W41 (Magic Blue, 64 GB)',
#        'Redmi 8A (Sunset Red, 32 GB)', 'realme 7 (Mist Blue, 64 GB)',
#        'SAMSUNG Galaxy S20 FE (Cloud Lavender, 128 GB)',
#        'SAMSUNG Galaxy A13 (Peach, 64 GB)',
#        'Redmi 8 (Sapphire Blue, 64 GB)', 'Itel It 5605n',
#        'SAMSUNG Galaxy A03s (Blue, 64 GB)',
#        'SAMSUNG Galaxy A52 (Awesome Violet, 128 GB)',
#        'realme GT Master Edition (Voyager Grey, 128 GB)',
#        'POCO M2 Pro (Two Shades of Black, 64 GB)',
#        'Infinix Hot 10S (7° Purple, 64 GB)',
#        'POCO F3 GT 5G (Predator Black, 128 GB)',
#        'Xiaomi 11T Pro 5G Hyperphone (Celestial Magic, 256 GB)',
#        'vivo Y20 (Obsidian Black, 64 GB)',
#        'vivo Y20 (Purist Blue, 64 GB)',
#        'SAMSUNG M53 5G (Emerald Brown, 128 GB)',
#        'SAMSUNG Galaxy A32 (Awesome Blue, 128 GB)',
#        'vivo Y20G (Purist Blue, 64 GB)', 'Redmi Note 5 Pro (Gold, 64 GB)',
#        'LAVA Gem', 'Infocus Star', 'LAVA 34 Ultra',
#        'realme 7 (Mist White, 64 GB)', 'Redmi 5A (Gold, 16 GB)',
#        'Redmi 5A (Grey, 16 GB)', 'Infinix Hot 10 (Moonlight Jade, 64 GB)',
#        'Redmi 6A (Gold, 32 GB)', 'POCO X2 (Matrix Purple, 64 GB)',
#        'SAMSUNG GURU 1200', 'Redmi K20 (Carbon Black, 64 GB)',
#        'vivo Y21 (Diamond Glow, 64 GB)',
#        'realme GT Neo 3 (Sprint White, 256 GB)',
#        'SAMSUNG Galaxy A03s (White, 64 GB)', 'Redmi 5A (Blue, 16 GB)',
#        'SAMSUNG Galaxy M01 (Black, 32 GB)',
#        'SAMSUNG Galaxy M52 5G (Blazing Black, 128 GB)',
#        'LG W41 Plus (Magic Blue, 128 GB)',
#        'Redmi Note 8 (Space Black, 64 GB)',
#        'POCO C3 (Matte Black, 32 GB)',
#        'realme GT Neo 3 (150W - Thor Limited Edition) (Nitro Blue, 256 GB)',
#        'REDMI Note 9 (Arctic White, 64 GB)',
#        'LAVA Z3 (Striped Blue, 32 GB)',
#        'Redmi 8A Dual (Sky White, 32 GB)',
#        'Redmi Note 7 Pro (Blue, 64 GB)',
#        'Redmi Note 7 Pro (Nebula Red, 64 GB)',
#        'Redmi 8 (Onyx Black, 64 GB)',
#        'Infinix Note 10 (7° Purple, 128 GB)',
#        'Mi 10i (Midnight Black, 128 GB)', 'Redmi 5A (Gold, 32 GB)',
#        'Infinix Hot 10S (95° Black, 64 GB)',
#        'MOTOROLA g82 5G (White Lily, 128 GB)',
#        'vivo V20 SE (Gravity Black, 128 GB)',
#        'POCO C3 (Arctic Blue, 32 GB)',
#        'realme GT NEO 3 (150W) (Sprint White, 256 GB)',
#        'realme C15 Qualcomm Edition (Power Blue, 32 GB)',
#        'REDMI 10 Prime (Astral White, 64 GB)',
#        'Redmi Note 8 (Neptune Blue, 64 GB)',
#        'SAMSUNG Galaxy A22 (Black, 128 GB)',
#        'Redmi Y3 (Elegant Blue, 32 GB)', 'Redmi 8 (Emerald Green, 64 GB)',
#        'realme GT Neo 3 (Nitro Blue, 128 GB)', 'KARBONN K24 Plus Pro',
#        'SAMSUNG Galaxy A21s (Blue, 64 GB)',
#        'realme GT Neo 3 (Sprint White, 128 GB)',
#        'realme GT Neo 3 (Asphalt Black, 128 GB)',
#        'SAMSUNG Galaxy A12 (White, 64 GB)', 'Redmi Note 4 (Gold, 32 GB)',
#        'vivo X60 (Midnight Black, 256 GB)',
#        'realme X50 Pro 5G (Rust Red, 256 GB)', 'KARBONN KX26i',
#        'realme 7i (Fusion Blue, 128 GB)',
#        'SAMSUNG Galaxy A10s (Black, 32 GB)',
#        'Itel vision 1 pro (OCEAN BLUE, 32 GB)',
#        'Mi 10T (Cosmic Black, 128 GB)', 'vivo X50 (Frost Blue, 256 GB)',
#        'POCO M3 (Power Black, 64 GB)',
#        'Redmi Note 11 (Space Black, 64 GB)',
#        'POCO F3 GT 5G (Predator Black, 256 GB)',
#        'Redmi Note 7S (Sapphire Blue, 64 GB)', 'POCO M3 (Yellow, 64 GB)',
#        'SAMSUNG Guru FM Plus', 'LAVA z61 (Midnight Blue, 16 GB)',
#        'realme GT 5G (Dashing Blue, 128 GB)', 'KARBONN K109 Star',
#        'vivo Y73 (Roman Black, 128 GB)',
#        'realme C15 Qualcomm Edition (Power Silver, 32 GB)',
#        'REDMI 10 Prime (Astral White, 128 GB)', 'LAVA Hero',
#        'SAMSUNG Galaxy A70s (Prism Crush White, 128 GB)',
#        'SAMSUNG Galaxy S20 FE (Cloud Navy, 128 GB)', 'Itel IT5626',
#        'Redmi Note 11 PRO Plus 5G (Mirage Blue, 128 GB)',
#        'Lava Pulse1- with contactless Talking Thermometer',
#        'REDMI 9 Power (Blazing Blue, 128 GB)',
#        'Itel A27 (Crystal Blue, 32 GB)',
#        'Redmi Note 7S (Sapphire Blue, 32 GB)',
#        'SAMSUNG Galaxy M02 (Red, 32 GB)', 'GIVA G1', 'Itel U10',
#        'realme X50 Pro (Moss Green, 256 GB)',
#        'Redmi K20 (Glacier Blue, 64 GB)',
#        'REDMI 9 Power (Electric Green, 64 GB)',
#        'realme Narzo 10 (That Blue, 128 GB)',
#        'Mi 10i (Pacific Sunrise, 128 GB)',
#        'realme X3 SuperZoom (Glacier Blue, 256 GB)',
#        'Redmi Note 6 Pro (Red, 64 GB)',
#        'Itel A25 (Gradation Sea Blue, 16 GB)', 'SAMSUNG Guru GT',
#        'SAMSUNG Galaxy S20 FE (Cloud Mint, 128 GB)',
#        'REDMI 9 Power (Fiery Red, 128 GB)',
#        'Itel Magic3 Smart Touch Keypad',
#        'REDMI NOTE 10 LITE (Glacier White, 64 GB)', 'KARBONN K31 Star',
#        'Infinix Hot 10S (Morandi Green, 64 GB)',
#        'Redmi K20 (Glacier Blue, 128 GB)', 'Infocus Star 1',
#        'Redmi Note 6 Pro (Blue, 64 GB)', 'GIVA G2',
#        'Redmi Note 6 Pro (Black, 64 GB)',
#        'SAMSUNG Galaxy M31 (Ocean Blue, 128 GB)',
#        'vivo Y20i (Dawn White, 64 GB)', 'Itel Heart Rate Edition',
#        'Mi 11X Pro 5G (Lunar White, 128 GB)',
#        'SAMSUNG Galaxy J6 (Blue, 32 GB)',
#        'Redmi Note 7 Pro (Moonlight White, 64 GB)',
#        'SAMSUNG Galaxy J6 (Black, 64 GB)', 'Redmi Y1 (Gold, 64 GB)',
#        'Redmi 7 (Comet Blue, 32 GB)', 'SAMSUNG Galaxy A03 (Blue, 32 GB)',
#        'REDMI Note 11S (Polar White, 128 GB)', 'Redmi 6 (Blue, 32 GB)',
#        'LAVA Z4 (Aqua Blue, 64 GB)',
#        'realme Narzo 20A (Glory Silver, 32 GB)', 'KARBONN KX23',
#        'SAMSUNG Galaxy A03 (Red, 64 GB)', 'Redmi Note 5 (Blue, 32 GB)',
#        'SAMSUNG Galaxy A33 (Awesome Peach, 128 GB)',
#        'realme 5 Pro (Sparkling Blue, 128 GB)',
#        'Redmi Note 7S (Onyx Black, 64 GB)',
#        'realme 5 Pro (Crystal Green, 64 GB)',
#        'vivo Y12G (Phantom Black, 64 GB)',
#        'REDMI 10A (Slate grey, 64 GB)', 'Redmi Y2 (Blue, 32 GB)',
#        'SAMSUNG Galaxy M21 (Midnight Blue, 64 GB)',
#        'realme GT 2 (Steel Black, 128 GB)',
#        'MOTOROLA edge 30 (Meteor Grey, 128 GB)',
#        'POCO X2 (Phoenix Red, 128 GB)', 'POCO F1 (Steel Blue, 128 GB)',
#        'realme 3i (Diamond Red, 64 GB)', 'POCO M3 (Cool Blue, 64 GB)',
#        'realme 5 Pro (Sparkling Blue, 64 GB)',
#        'realme 6 Pro (Lightning Red, 64 GB)', 'Mi Max 2 (Black, 64 GB)',
#        'vivo U10 (Electric Blue, 64 GB)', 'Mi A1 (Black, 64 GB)',
#        'Infocus Hero Play M1', 'POCO F1 (Graphite Black, 64 GB)',
#        'SAMSUNG M31 Prime (Space Black, 128 GB)', 'KARBONN KU3',
#        'REDMI Note 8 Pro (Shadow Black, 128 GB)',
#        'SAMSUNG Galaxy A12 (Blue, 64 GB)',
#        'SAMSUNG Galaxy A33 (Awesome Blue, 128 GB)', 'LAVA Hero ONE',
#        'MOTOROLA e32s (Misty Silver, 64 GB)',
#        'Redmi 7A (Matte Blue, 32 GB)',
#        'Redmi Note 5 Pro (Rose Gold, 64 GB)',
#        'Infinix Note 5 (Ice Blue, 32 GB)', 'Redmi 8A (Ocean Blue, 32 GB)',
#        'GIVA G4', 'POCO M2 (Slate Blue, 128 GB)',
#        'SAMSUNG Galaxy J8 (Blue, 64 GB)',
#        'Mi A3 (More Than White, 128 GB)',
#        'MOTOROLA G8 Power Lite (Arctic Blue, 64 GB)',
#        'realme C3 (Frozen Blue, 64 GB)',
#        'Moto G8 Plus (Cosmic Blue, 64 GB)',
#        'Lava Pulse Mobile Phone-With BP & Heart Rate Monitor',
#        'Redmi Note 4 (Black, 64 GB)', 'Redmi K20 (Carbon Black, 128 GB)',
#        'vivo Y95 (Starry Black, 64 GB)',
#        'Infinix Note 10 (95° Black, 64 GB)',
#        'REDMI 9i (Midnight Black, 128 GB)', 'Redmi Note 5 (Black, 64 GB)',
#        'POCO F1 (Steel Blue, 64 GB)',
#        'REDMI Note 9 Pro Max (Glacier White, 128 GB)', 'Itel Ace 2',
#        'realme 3i (Diamond Black, 64 GB)',
#        'realme 3i (Diamond Blue, 32 GB)', 'vivo Y83 (Gold, 32 GB)',
#        'Moto E6s (Caribbean Blue, 64 GB)', 'Redmi 7A (Matte Gold, 32 GB)',
#        'REDMI Note 10 Pro (Vintage Bronze, 64 GB)',
#        'Panasonic Eluga A3 (Gold, 16 GB)',
#        'SAMSUNG Galaxy A50 (Blue, 64 GB)',
#        'vivo Y95 (Nebula Purple, 64 GB)', 'Redmi 6 (Rose Gold, 32 GB)',
#        'SAMSUNG Galaxy M11 (Metallic Blue, 64 GB)',
#        'Lenovo K10 Plus (Black, 64 GB)',
#        'REDMI 8A Dual (Sky White, 32 GB)', 'Redmi 4A (Dark Grey, 32 GB)',
#        'Lenovo K9 Note (Gold, 64 GB)',
#        'realme 8 Pro (Infinite Black, 128 GB)',
#        'LAVA Blaze (Glass Black, 64 GB)', 'vivo Y81i (Black, 16 GB)',
#        'realme 3i (Diamond Black, 32 GB)',
#        'SAMSUNG Galaxy A50 (White, 64 GB)',
#        'realme 6 (Comet Blue, 64 GB)', 'KARBONN KU3 power',
#        'Mi A2 (Red, 64 GB)'], dtype=object)

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  ₹13,999
# 980                   KARBONN KU3 power   ₹1,199
# 981                  Mi A2 (Red, 64 GB)  ₹17,499
# 982                   KARBONN KU3 power   ₹1,199
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  ₹15,985
#
#                                         specifications rating  pagenumber
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41

# %%
mobile_df['productname'] = mobile_df['productname'].apply(lambda x: ''.join(x))

# %%
mobile_df['price'] = mobile_df['price'].apply(lambda x: ''.join(x))

# %%
mobile_df.to_csv('mobile_df.csv')

# %%
mobile_df['productname'][5]
# Out:
# 'realme 9 (Sunburst Gold, 128 GB)'

# %%
mobile_df['specifications'][0]
# Out:
# '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB16.59 cm (6.53 inch) HD+ Display13MP + 2MP + 2MP | 5MP Front Camera5000 mAh Lithium-ion Polymer BatteryMediaTek Helio G35 Processor1 Year Warranty for Handset, 6 Months for Accessories'

# %%
# extract brand
regex = r'^\w+'
mobile_df['brand']= mobile_df['productname'].apply(lambda x: re.compile(regex).findall(x))

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  ₹13,999
# 980                   KARBONN KU3 power   ₹1,199
# 981                  Mi A2 (Red, 64 GB)  ₹17,499
# 982                   KARBONN KU3 power   ₹1,199
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  ₹15,985
#
#                                         specifications rating  pagenumber  \
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41
#
#          brand
# 979   [realme]
# 980  [KARBONN]
# 981       [Mi]
# 982  [KARBONN]
# 983  [SAMSUNG]

# %%
# extract RAM
regex = r'[0-9]+\s(?:MB|GB)\s+RAM'
mobile_df['RAM']= mobile_df['specifications'].apply(lambda x: re.compile(regex).findall(x))

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  ₹13,999
# 980                   KARBONN KU3 power   ₹1,199
# 981                  Mi A2 (Red, 64 GB)  ₹17,499
# 982                   KARBONN KU3 power   ₹1,199
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  ₹15,985
#
#                                         specifications rating  pagenumber  \
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41
#
#          brand          RAM
# 979   [realme]   [4 GB RAM]
# 980  [KARBONN]  [32 MB RAM]
# 981       [Mi]   [4 GB RAM]
# 982  [KARBONN]  [32 MB RAM]
# 983  [SAMSUNG]   [6 GB RAM]

# %%
# extract storage
regex = r'[0-9\s]+(?:MB|GB)\s+ROM'
mobile_df['storage']= mobile_df['specifications'].apply(lambda x: re.compile(regex).findall(x))

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  ₹13,999
# 980                   KARBONN KU3 power   ₹1,199
# 981                  Mi A2 (Red, 64 GB)  ₹17,499
# 982                   KARBONN KU3 power   ₹1,199
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  ₹15,985
#
#                                         specifications rating  pagenumber  \
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41
#
#          brand          RAM        storage
# 979   [realme]   [4 GB RAM]   [ 64 GB ROM]
# 980  [KARBONN]  [32 MB RAM]   [ 32 MB ROM]
# 981       [Mi]   [4 GB RAM]   [ 64 GB ROM]
# 982  [KARBONN]  [32 MB RAM]   [ 32 MB ROM]
# 983  [SAMSUNG]   [6 GB RAM]  [ 128 GB ROM]

# %%
# extract colour
regex = r'\w+,'
mobile_df['colour']= mobile_df['productname'].apply(lambda x: re.compile(regex).findall(x))

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  ₹13,999
# 980                   KARBONN KU3 power   ₹1,199
# 981                  Mi A2 (Red, 64 GB)  ₹17,499
# 982                   KARBONN KU3 power   ₹1,199
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  ₹15,985
#
#                                         specifications rating  pagenumber  \
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41
#
#          brand          RAM        storage    colour
# 979   [realme]   [4 GB RAM]   [ 64 GB ROM]   [Blue,]
# 980  [KARBONN]  [32 MB RAM]   [ 32 MB ROM]        []
# 981       [Mi]   [4 GB RAM]   [ 64 GB ROM]    [Red,]
# 982  [KARBONN]  [32 MB RAM]   [ 32 MB ROM]        []
# 983  [SAMSUNG]   [6 GB RAM]  [ 128 GB ROM]  [Black,]

# %%
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   productname     984 non-null    object
#  1   price           984 non-null    object
#  2   specifications  984 non-null    object
#  3   rating          975 non-null    object
#  4   pagenumber      984 non-null    int64
#  5   brand           984 non-null    object
#  6   RAM             984 non-null    object
#  7   storage         984 non-null    object
#  8   colour          984 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 69.3+ KB

# %%
mobile_df.isnull().sum()
# Out:
# productname       0
# price             0
# specifications    0
# rating            9
# pagenumber        0
# brand             0
# RAM               0
# storage           0
# colour            0
# dtype: int64

# %%
mobile_df['brand'] = mobile_df['brand'].apply(lambda x: ''.join(x))
mobile_df['RAM'] = mobile_df['RAM'].apply(lambda x: ''.join(x))
mobile_df['storage'] = mobile_df['storage'].apply(lambda x: ''.join(x))
mobile_df['colour'] = mobile_df['colour'].apply(lambda x : ''.join(x))
mobile_df['price'] = mobile_df['price'].apply(lambda x: x.replace('₹','').replace(",",'')).astype(float)
mobile_df['colour'] = mobile_df['colour'].apply(lambda x: x.replace(',',''))

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  13999.0
# 980                   KARBONN KU3 power   1199.0
# 981                  Mi A2 (Red, 64 GB)  17499.0
# 982                   KARBONN KU3 power   1199.0
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  15985.0
#
#                                         specifications rating  pagenumber  \
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...    NaN          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41
#
#        brand        RAM      storage colour
# 979   realme   4 GB RAM    64 GB ROM   Blue
# 980  KARBONN  32 MB RAM    32 MB ROM
# 981       Mi   4 GB RAM    64 GB ROM    Red
# 982  KARBONN  32 MB RAM    32 MB ROM
# 983  SAMSUNG   6 GB RAM   128 GB ROM  Black

# %%
mobile_df.isnull().sum()
# Out:
# productname       0
# price             0
# specifications    0
# rating            9
# pagenumber        0
# brand             0
# RAM               0
# storage           0
# colour            0
# dtype: int64

# %%
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   productname     984 non-null    object
#  1   price           984 non-null    float64
#  2   specifications  984 non-null    object
#  3   rating          975 non-null    object
#  4   pagenumber      984 non-null    int64
#  5   brand           984 non-null    object
#  6   RAM             984 non-null    object
#  7   storage         984 non-null    object
#  8   colour          984 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 69.3+ KB

# %%
mobile_df = mobile_df.fillna(0)

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  13999.0
# 980                   KARBONN KU3 power   1199.0
# 981                  Mi A2 (Red, 64 GB)  17499.0
# 982                   KARBONN KU3 power   1199.0
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  15985.0
#
#                                         specifications rating  pagenumber  \
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...      0          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...      0          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41
#
#        brand        RAM      storage colour
# 979   realme   4 GB RAM    64 GB ROM   Blue
# 980  KARBONN  32 MB RAM    32 MB ROM
# 981       Mi   4 GB RAM    64 GB ROM    Red
# 982  KARBONN  32 MB RAM    32 MB ROM
# 983  SAMSUNG   6 GB RAM   128 GB ROM  Black

# %%
mobile_df = mobile_df.replace(r'^\s*$', np.nan, regex=True)

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  13999.0
# 980                   KARBONN KU3 power   1199.0
# 981                  Mi A2 (Red, 64 GB)  17499.0
# 982                   KARBONN KU3 power   1199.0
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  15985.0
#
#                                         specifications rating  pagenumber  \
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...      0          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...      0          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41
#
#        brand        RAM      storage colour
# 979   realme   4 GB RAM    64 GB ROM   Blue
# 980  KARBONN  32 MB RAM    32 MB ROM    NaN
# 981       Mi   4 GB RAM    64 GB ROM    Red
# 982  KARBONN  32 MB RAM    32 MB ROM    NaN
# 983  SAMSUNG   6 GB RAM   128 GB ROM  Black

# %%
mobile_df = mobile_df.fillna(0)

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 979        realme 6 (Comet Blue, 64 GB)  13999.0
# 980                   KARBONN KU3 power   1199.0
# 981                  Mi A2 (Red, 64 GB)  17499.0
# 982                   KARBONN KU3 power   1199.0
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  15985.0
#
#                                         specifications rating  pagenumber  \
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...    4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...      0          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...    4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...      0          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...    4.2          41
#
#        brand        RAM      storage colour
# 979   realme   4 GB RAM    64 GB ROM   Blue
# 980  KARBONN  32 MB RAM    32 MB ROM      0
# 981       Mi   4 GB RAM    64 GB ROM    Red
# 982  KARBONN  32 MB RAM    32 MB ROM      0
# 983  SAMSUNG   6 GB RAM   128 GB ROM  Black

# %%
mobile_df.isnull().sum()
# Out:
# productname       0
# price             0
# specifications    0
# rating            0
# pagenumber        0
# brand             0
# RAM               0
# storage           0
# colour            0
# dtype: int64

# %%
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   productname     984 non-null    object
#  1   price           984 non-null    float64
#  2   specifications  984 non-null    object
#  3   rating          984 non-null    object
#  4   pagenumber      984 non-null    int64
#  5   brand           984 non-null    object
#  6   RAM             984 non-null    object
#  7   storage         984 non-null    object
#  8   colour          984 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 69.3+ KB

# %%
mobile_df['rating'] = mobile_df['rating'].astype(float)

# %%
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   productname     984 non-null    object
#  1   price           984 non-null    float64
#  2   specifications  984 non-null    object
#  3   rating          984 non-null    float64
#  4   pagenumber      984 non-null    int64
#  5   brand           984 non-null    object
#  6   RAM             984 non-null    object
#  7   storage         984 non-null    object
#  8   colour          984 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 69.3+ KB

# %%
# measure of central tendency
mobile_df.describe()
# Out:
#               price      rating  pagenumber
# count    984.000000  984.000000  984.000000
# mean   13592.227642    4.189126   21.000000
# std     9107.759662    0.443942   11.838176
# min      749.000000    0.000000    1.000000
# 25%     7998.750000    4.100000   11.000000
# 50%    12999.000000    4.300000   21.000000
# 75%    17990.000000    4.400000   31.000000
# max    49999.000000    5.000000   41.000000

# %%
mobile_df['brand'] = mobile_df['brand'].apply(lambda x: x.replace('LAVA','Lava').replace('REDMI','Redmi').replace('MOTOROLA','Motorola').replace('Mi','Redmi').replace('Motorola','Moto').replace('Xiaomi','Redmi'))

# %%
mobile_df
# Out:
#                                    productname    price  \
# 0                 POCO C31 (Royal Blue, 64 GB)   7999.0
# 1                POCO C31 (Shadow Gray, 64 GB)   7999.0
# 2                 POCO C31 (Royal Blue, 32 GB)   6999.0
# 3       SAMSUNG Galaxy F22 (Denim Blue, 64 GB)  10499.0
# 4    Infinix HOT 12 Play (Horizon Blue, 64 GB)   8499.0
# ..                                         ...      ...
# 979               realme 6 (Comet Blue, 64 GB)  13999.0
# 980                          KARBONN KU3 power   1199.0
# 981                         Mi A2 (Red, 64 GB)  17499.0
# 982                          KARBONN KU3 power   1199.0
# 983         SAMSUNG Galaxy M32 (Black, 128 GB)  15985.0
#
#                                         specifications  rating  pagenumber  \
# 0    4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...     4.4           1
# 1    4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...     4.4           1
# 2    3 GB RAM | 32 GB ROM | Expandable Upto 512 GB1...     4.4           1
# 3    4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....     4.3           1
# 4    4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...     4.3           1
# ..                                                 ...     ...         ...
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...     4.4          41
# 980  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...     0.0          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...     4.2          41
# 982  32 MB RAM | 32 MB ROM4.57 cm (1.8 inch) Displa...     0.0          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...     4.2          41
#
#        brand        RAM      storage colour
# 0       POCO   4 GB RAM    64 GB ROM   Blue
# 1       POCO   4 GB RAM    64 GB ROM   Gray
# 2       POCO   3 GB RAM    32 GB ROM   Blue
# 3    SAMSUNG   4 GB RAM    64 GB ROM   Blue
# 4    Infinix   4 GB RAM    64 GB ROM   Blue
# ..       ...        ...          ...    ...
# 979   realme   4 GB RAM    64 GB ROM   Blue
# 980  KARBONN  32 MB RAM    32 MB ROM      0
# 981    Redmi   4 GB RAM    64 GB ROM    Red
# 982  KARBONN  32 MB RAM    32 MB ROM      0
# 983  SAMSUNG   6 GB RAM   128 GB ROM  Black
#
# [984 rows x 9 columns]

# %% [markdown]
# ## removing outliers

# %%
mobile_df.describe()
# Out:
#               price      rating  pagenumber
# count    984.000000  984.000000  984.000000
# mean   13592.227642    4.189126   21.000000
# std     9107.759662    0.443942   11.838176
# min      749.000000    0.000000    1.000000
# 25%     7998.750000    4.100000   11.000000
# 50%    12999.000000    4.300000   21.000000
# 75%    17990.000000    4.400000   31.000000
# max    49999.000000    5.000000   41.000000

# %%
min_thresold = mobile_df.price.quantile(0.20)
min_thresold
# Out:
# 6830.6

# %%
mobile_df = mobile_df[(mobile_df.price>min_thresold)]

# %%
mobile_df.tail()
# Out:
#                             productname    price  \
# 977    realme 3i (Diamond Black, 32 GB)   8499.0
# 978   SAMSUNG Galaxy A50 (White, 64 GB)  18999.0
# 979        realme 6 (Comet Blue, 64 GB)  13999.0
# 981                  Mi A2 (Red, 64 GB)  17499.0
# 983  SAMSUNG Galaxy M32 (Black, 128 GB)  15985.0
#
#                                         specifications  rating  pagenumber  \
# 977  3 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...     4.4          41
# 978  6 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...     4.4          41
# 979  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...     4.4          41
# 981  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...     4.2          41
# 983  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...     4.2          41
#
#        brand       RAM      storage colour
# 977   realme  3 GB RAM    32 GB ROM  Black
# 978  SAMSUNG  6 GB RAM    64 GB ROM  White
# 979   realme  4 GB RAM    64 GB ROM   Blue
# 981    Redmi  4 GB RAM    64 GB ROM    Red
# 983  SAMSUNG  6 GB RAM   128 GB ROM  Black

# %%
mobile_df.reset_index(inplace=True)

# %%
mobile_df
# Out:
#      index                                productname    price  \
# 0        0               POCO C31 (Royal Blue, 64 GB)   7999.0
# 1        1              POCO C31 (Shadow Gray, 64 GB)   7999.0
# 2        2               POCO C31 (Royal Blue, 32 GB)   6999.0
# 3        3     SAMSUNG Galaxy F22 (Denim Blue, 64 GB)  10499.0
# 4        4  Infinix HOT 12 Play (Horizon Blue, 64 GB)   8499.0
# ..     ...                                        ...      ...
# 782    977           realme 3i (Diamond Black, 32 GB)   8499.0
# 783    978          SAMSUNG Galaxy A50 (White, 64 GB)  18999.0
# 784    979               realme 6 (Comet Blue, 64 GB)  13999.0
# 785    981                         Mi A2 (Red, 64 GB)  17499.0
# 786    983         SAMSUNG Galaxy M32 (Black, 128 GB)  15985.0
#
#                                         specifications  rating  pagenumber  \
# 0    4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...     4.4           1
# 1    4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...     4.4           1
# 2    3 GB RAM | 32 GB ROM | Expandable Upto 512 GB1...     4.4           1
# 3    4 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....     4.3           1
# 4    4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...     4.3           1
# ..                                                 ...     ...         ...
# 782  3 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...     4.4          41
# 783  6 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...     4.4          41
# 784  4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...     4.4          41
# 785  4 GB RAM | 64 GB ROM15.21 cm (5.99 inch) Full ...     4.2          41
# 786  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...     4.2          41
#
#        brand       RAM      storage colour
# 0       POCO  4 GB RAM    64 GB ROM   Blue
# 1       POCO  4 GB RAM    64 GB ROM   Gray
# 2       POCO  3 GB RAM    32 GB ROM   Blue
# 3    SAMSUNG  4 GB RAM    64 GB ROM   Blue
# 4    Infinix  4 GB RAM    64 GB ROM   Blue
# ..       ...       ...          ...    ...
# 782   realme  3 GB RAM    32 GB ROM  Black
# 783  SAMSUNG  6 GB RAM    64 GB ROM  White
# 784   realme  4 GB RAM    64 GB ROM   Blue
# 785    Redmi  4 GB RAM    64 GB ROM    Red
# 786  SAMSUNG  6 GB RAM   128 GB ROM  Black
#
# [787 rows x 10 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ### univariate analysis

# %%
plt.figure(figsize=(15, 7))
mobile_df.groupby(['brand'])['price'].max().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='brand'>

# %%
mobile_df['price'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(25,10))
sns.countplot(mobile_df.brand)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='count'>

# %%
plt.figure(figsize=(25,10))
sns.countplot(mobile_df.rating)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
sns.boxplot(y=mobile_df['price'])
# Out:
# <AxesSubplot:ylabel='price'>

# %%
sns.boxplot(y=mobile_df['rating'])
# Out:
# <AxesSubplot:ylabel='rating'>

# %% [markdown]
# ### multivariate

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x = mobile_df.brand, y = mobile_df.price)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='price'>

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x = mobile_df.brand, y = mobile_df.rating)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='rating'>

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x = mobile_df.brand, y = mobile_df.price)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='price'>
